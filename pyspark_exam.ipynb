# %%
# filename=r"C:\Users\25004\Desktop\t_exam_paper_answer.csv"
# 表头 
filename=r"C:\Users\25004\Desktop\t_exam_paper_answer(2).csv"

# %% [markdown]
# 1 pip install -i https://pypi.tuna.tsinghua.edu.cn/simple some-package
#
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple   notebook
#
# D:\software\anaconda\envs\py374\Scripts jupyter notebook D:\proj\python\my_util_py_pub\record.py

# %%
# !pip install pyspark -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# ...
#      -------------------------------------- 281.4/281.4 MB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------ 199.7/199.7 kB 485.9 kB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845525 sha256=8fe760171ef733e7191a9adb01da12c5f0655ac6d8fe15c68bf7501493d4726c
#   Stored in directory: c:\users\25004\appdata\local\pip\cache\wheels\42\59\f5\79a5bf931714dcd201b26025347785f087370a10a3329a899c
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .enableHiveSupport().getOrCreate()
# df = spark.read.csv(filename)
# df.printSchema()
##可以得到
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)
#  |-- _c9: string (nullable = true)
#  |-- _c10: string (nullable = true)
#  |-- _c11: string (nullable = true)
#  |-- _c12: string (nullable = true)
#  |-- _c13: string (nullable = true)
#  |-- _c14: string (nullable = true)

# %%
df = spark.read.csv(filename,header=True)
df.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- exam_paper_id: string (nullable = true)
#  |-- paper_name: string (nullable = true)
#  |-- paper_type: string (nullable = true)
#  |-- subject_id: string (nullable = true)
#  |-- system_score: string (nullable = true)
#  |-- user_score: string (nullable = true)
#  |-- paper_score: string (nullable = true)
#  |-- question_correct: string (nullable = true)
#  |-- question_count: string (nullable = true)
#  |-- do_time: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- create_user: string (nullable = true)
#  |-- create_time: string (nullable = true)
#  |-- task_exam_id: string (nullable = true)

# %% [markdown]
# ModuleNotFoundError: No module named 'pyspark'

# %%
# !pip install pandas -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/b2/56/f886ed6f1777ffa9d54c6e80231b69db8a1f52dcc33f5967b06a105dcfe0/pandas-1.3.5-cp37-cp37m-win_amd64.whl (10.0 MB)
# ...

# %%
df.toPandas()
# Out:
#     id exam_paper_id     paper_name paper_type subject_id system_score  \
# 0    1            12  java基础知识测试（一）          1          4          100
# 1    2            13  Java基础知识测试（二）          1          4           40
# 2    3            14  java基础知识测试（三）          1          4            0
# 3    4            15          智能试卷1          8          4           30
# 4    5            29          智能训练1          8          4            0
# 5    6            13  Java基础知识测试（二）          1          4           50
# 6    7            45          智能试卷1         10          4           20
# 7    8            55          智能试卷7         10          4           20
# 8    9            46          智能训练1          8          4            0
# 9   10            79          智能训练2          8          4           20
# 10  11            82          智能训练4          8          4           20
# 11  12            89         智能训练10          8          4            0
# ...

# %% [markdown]
# 最终得分(千分制)
# 根据 排名 pyspark
# pyspark 分组排序，按分区内的排序标上序号_sijin_190527的博客-CSDN博客_pyspark 分组排序
# https://blog.csdn.net/sijin_190527/article/details/121754087

# %% [markdown]
# import

# %% [markdown]
# from py

# %%
from pyspark import copy_func
from pyspark import func

# %%
from pyspark.sql import functions as F

# %%
from pyspark.sql.window import Window
 
window = Window.partitionBy('exam_paper_id').orderBy(df.user_score.desc())
df_top_n = df.withColumn('top_n', F.rank().over(window))
 
 
#group是分组字段
#count是排序字段
#topn是新增字段，用来存储排序序号

# %% [markdown]
# AnalysisException: Column 'group' does not exist. Did you mean one of the following? [

# %%
df_top_n.toPandas()
# Out:
#     id exam_paper_id     paper_name paper_type subject_id system_score  \
# 0    1            12  java基础知识测试（一）          1          4          100
# 1    6            13  Java基础知识测试（二）          1          4           50
# 2    2            13  Java基础知识测试（二）          1          4           40
# 3    3            14  java基础知识测试（三）          1          4            0
# 4    4            15          智能试卷1          8          4           30
# 5    5            29          智能训练1          8          4            0
# 6    7            45          智能试卷1         10          4           20
# 7    9            46          智能训练1          8          4            0
# 8    8            55          智能试卷7         10          4           20
# 9   10            79          智能训练2          8          4           20
# 10  11            82          智能训练4          8          4           20
# 11  12            89         智能训练10          8          4            0
# ...

# %%
df_top_n.columns
# Out:
# ['id',
#  'exam_paper_id',
#  'paper_name',
#  'paper_type',
#  'subject_id',
#  'system_score',
#  'user_score',
#  'paper_score',
#  'question_correct',
#  'question_count',
#  'do_time',
#  'status',
#  'create_user',
#  'create_time',
#  'task_exam_id',
#  'top_n']

# %%
ImportError: Pandas >= 1.0.5 must be installed; however, it was not found.

# %%
df_top_n.select(df_top_n.top_n,"paper_name","user_score","create_user").toPandas()
# Out:
#     top_n     paper_name user_score create_user
# 0       1  java基础知识测试（一）        100           6
# 1       1  Java基础知识测试（二）         50           6
# 2       2  Java基础知识测试（二）         40           6
# 3       1  java基础知识测试（三）         50           6
# 4       1          智能试卷1         80           6
# 5       1          智能训练1          0           6
# 6       1          智能试卷1         50           6
# 7       1          智能训练1         20           6
# 8       1          智能试卷7         80           6
# 9       1          智能训练2        100           6
# 10      1          智能训练4         60           6
# 11      1         智能训练10        100           6
# 12      1         智能训练12         30           6
# 13      1          智能试卷1        140           6
# 14      1           java         10           8
# 15      1           java         10           6
# 16      1           java         10           8
# 17      1           java         10           6
# 18      1           java         10           6
# ...

# %%
df_top_n.select(df_top_n.top_n,"paper_name","user_score","create_user","paper_score").toPandas()
# Out:
#     top_n     paper_name user_score create_user paper_score
# 0       1  java基础知识测试（一）        100           6         180
# 1       1  Java基础知识测试（二）         50           6          80
# 2       2  Java基础知识测试（二）         40           6          80
# 3       1  java基础知识测试（三）         50           6          50
# 4       1          智能试卷1         80           6         100
# 5       1          智能训练1          0           6         140
# 6       1          智能试卷1         50           6         350
# 7       1          智能训练1         20           6         230
# 8       1          智能试卷7         80           6         350
# 9       1          智能训练2        100           6         210
# 10      1          智能训练4         60           6          90
# 11      1         智能训练10        100           6         110
# 12      1         智能训练12         30           6          50
# 13      1          智能试卷1        140           6         350
# 14      1           java         10           8          10
# ...

# %%
df_top_n.withColumn("score_percent",F.col("user_score")/F.col("paper_score")).toPandas()
# Out:
#     id exam_paper_id     paper_name paper_type subject_id system_score  \
# 0    1            12  java基础知识测试（一）          1          4          100
# 1    6            13  Java基础知识测试（二）          1          4           50
# 2    2            13  Java基础知识测试（二）          1          4           40
# 3    3            14  java基础知识测试（三）          1          4            0
# 4    4            15          智能试卷1          8          4           30
# 5    5            29          智能训练1          8          4            0
# 6    7            45          智能试卷1         10          4           20
# 7    9            46          智能训练1          8          4            0
# 8    8            55          智能试卷7         10          4           20
# 9   10            79          智能训练2          8          4           20
# 10  11            82          智能训练4          8          4           20
# 11  12            89         智能训练10          8          4            0
# ...

# %%
df_top_n=df_top_n.withColumn("score_percent",F.col("user_score")/F.col("paper_score")*100)

# %%
def get_percent():
    # F.round((F.col('Month_start')/F.col('Month_end'))*100,2))
    _100=(F.col("user_score")/F.col("paper_score"))*100
    return F.round(_100,2)

# %%
df_top_n=df_top_n.withColumn("score_percent",get_percent)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39304\3809146599.py in <module>
# ----> 1 df_top_n=df_top_n.withColumn("score_percent",get_percent)
#
# d:\software\anaconda\envs\py374\lib\site-packages\pyspark\sql\dataframe.py in withColumn(self, colName, col)
#    3033         """
#    3034         if not isinstance(col, Column):
# -> 3035             raise TypeError("col should be Column")
#    3036         return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#    3037
#
# TypeError: col should be Column

# %%
df_top_n=df_top_n.withColumn("score_percent",F.round((F.col("user_score")/F.col("paper_score"))*100,2))

# %% [markdown]
# F.round 可以单独写一个函数

# %%
from pyspark.sql.functions import col, udf

# %%
convertUDF = udf(lambda z: convertCase(z))

# %%
convertUDF = udf(lambda z: get_percent(z))

# %%
df_top_n.toPandas()
# Out:
#     id exam_paper_id     paper_name paper_type subject_id system_score  \
# 0    1            12  java基础知识测试（一）          1          4          100
# 1    6            13  Java基础知识测试（二）          1          4           50
# 2    2            13  Java基础知识测试（二）          1          4           40
# 3    3            14  java基础知识测试（三）          1          4            0
# 4    4            15          智能试卷1          8          4           30
# 5    5            29          智能训练1          8          4            0
# 6    7            45          智能试卷1         10          4           20
# 7    9            46          智能训练1          8          4            0
# 8    8            55          智能试卷7         10          4           20
# 9   10            79          智能训练2          8          4           20
# 10  11            82          智能训练4          8          4           20
# 11  12            89         智能训练10          8          4            0
# ...

# %%
df_top_n.select(df_top_n.top_n,"paper_name","user_score","create_user","paper_score","score_percent").toPandas()
# Out:
#     top_n     paper_name user_score create_user paper_score  score_percent
# 0       1  java基础知识测试（一）        100           6         180          55.56
# 1       1  Java基础知识测试（二）         50           6          80          62.50
# 2       2  Java基础知识测试（二）         40           6          80          50.00
# 3       1  java基础知识测试（三）         50           6          50         100.00
# 4       1          智能试卷1         80           6         100          80.00
# 5       1          智能训练1          0           6         140           0.00
# 6       1          智能试卷1         50           6         350          14.29
# 7       1          智能训练1         20           6         230           8.70
# 8       1          智能试卷7         80           6         350          22.86
# 9       1          智能训练2        100           6         210          47.62
# 10      1          智能训练4         60           6          90          66.67
# ...

# %% [markdown]
# TypeError: col should be Column
# 断言错误：col应该是Column - 问答 - Python中文网
# https://www.cnpython.com/qa/44335

# %% [markdown]
# pyspark 保留2位小数

# %%
df_top_n.select(df_top_n.top_n,"paper_name","user_score","create_user","paper_score","score_percent").toPandas()
# Out:
#     top_n     paper_name user_score create_user paper_score  score_percent
# 0       1  java基础知识测试（一）        100           6         180      55.555556
# 1       1  Java基础知识测试（二）         50           6          80      62.500000
# 2       2  Java基础知识测试（二）         40           6          80      50.000000
# 3       1  java基础知识测试（三）         50           6          50     100.000000
# 4       1          智能试卷1         80           6         100      80.000000
# 5       1          智能训练1          0           6         140       0.000000
# 6       1          智能试卷1         50           6         350      14.285714
# 7       1          智能训练1         20           6         230       8.695652
# 8       1          智能试卷7         80           6         350      22.857143
# 9       1          智能训练2        100           6         210      47.619048
# 10      1          智能训练4         60           6          90      66.666667
# ...

# %% [markdown]
# pyspark 转化为百分之

# %% [markdown]
# pyspark 只是 显示几列
# 如何在PySpark中只打印某一列DataFrame？ |
# https://qa.1r1g.com/sf/ask/2513945451/

# %%
如何在PySpark中只打印某一列DataFrame？ |
https://qa.1r1g.com/sf/ask/2513945451/

# %% [markdown]
# ImportError: Pandas >= 1.0.5 must be installed; however, it was not found.

# %%
# data = spark.read
#     .option("inferSchema","true")#自动推导数据类型
#     .option("header","true")#读取列名
#     .csv("/user/root/image.csv")#文件路径

# %%
# D:\records_singleArray.json

filename_records_singleArray=r"D:\records_singleArray.json"

# %% [markdown]
# pyspark 读取 json

# %%
readJSONDF = spark.read.json(filename_records_singleArray)

# %%
readJSONDF.show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39304\451247490.py in <module>
# ----> 1 readJSONDF.show()
#
# d:\software\anaconda\envs\py374\lib\site-packages\pyspark\sql\dataframe.py in show(self, n, truncate, vertical)
#     604
#     605         if isinstance(truncate, bool) and truncate:
# --> 606             print(self._jdf.showString(n, 20, vertical))
#     607         else:
#     608             try:
#
# d:\software\anaconda\envs\py374\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
# -> 1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#    1324         for temp_arg in temp_args:
#
# d:\software\anaconda\envs\py374\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
# ...

# %%
readJSONDF.toPandas()
# Out:
#    answer  choice1  difficulty  id  pointId  score  type  userId
# 0      31  choise3        10.0   0        8    2.0     1       0
# 1      31  choise3         4.0   0        6    2.0     1       0
# 2      31  choise3        10.0   0        8    2.0     1       0
# 3      31  choise3         3.0   0       10    2.0     1       0
# 4      31  choise3        10.0   0        8    2.0     1       0
# 5      31  choise3         3.0   0       10    2.0     1       0
# 6      31  choise3         4.0   0        6    2.0     1       0
# 7      31  choise3        10.0   0        8    2.0     1       0
# 8      31  choise3        10.0   0        8    2.0     1       0
# 9      31  choise3        10.0   0        8    2.0     1       0
# 10     31  choise3         3.0   0        1    2.0     1       0
# 11     31  choise3         4.0   0        6    2.0     1       0
# 12     31  choise3        10.0   0        8    2.0     1       0
# ...
